# %% [markdown]
# # Read C3D Export Text File
#
# Read the exported file. Put into format for Pandas.
#
# Want to create variables that can be easily looped through for the visual
#
# Want to remove the VPython part so my computer doesnt work as hard

# %%
import csv #used for reading and parsing data from a text file
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#get the empty rows
filename='clean_cmj.txt'
datafile = csv.reader(open(filename, 'r'), delimiter='\t')

counter = 0 #counter for number of rows
empty_rows = []
for row in datafile:
    if len(row)==0: #test for an empty row
        empty_rows.append(counter)    
    counter += 1
print(empty_rows)
# Out:
# [4, 272, 540, 2127]

# %%
# get position data
datafile = csv.reader(open(filename, 'r'), delimiter='\t')
counter = 0 #counter for number of rows
pos_header = []
pos_units = []
pos_direction = []
pos_data = []
for row in datafile:
    if counter==empty_rows[0]+1:
        pos_header.append(row)
    elif counter==empty_rows[0]+2:
        pos_units.append(row)
    elif counter==empty_rows[0]+3:
        pos_direction.append(row)
    elif counter>empty_rows[0]+3 and counter<empty_rows[1] :
        pos_data.append(row)
    elif counter>=empty_rows[1]:
        break
    counter = counter + 1

# %%
pos_head_unit = []
counter = 0
for i in range(len(pos_header[0])):
    if i == 0:
        head_plus_unit = pos_header[0][i]
        pos_head_unit.append(head_plus_unit)
    else:
        if counter == 0:
            head_plus_unit = pos_header[0][i] +  '_'  +   pos_direction[0][i]
            pos_head_unit.append(head_plus_unit) 
        else:
            head_plus_unit = pos_header[0][i-counter] +  '_'  + pos_direction[0][i] 
            pos_head_unit.append(head_plus_unit)    
            
        counter += 1
        if counter == 3:
            counter = 0

# %%
df = pd.DataFrame(pos_data, columns=pos_head_unit)
df
# Out:
#       Time L.Trunk_X L.Trunk_Y L.Trunk_Z R.Trunk_X R.Trunk_Y R.Trunk_Z  \
# 0    1.995   584.802   368.122   1463.72   696.778   344.382   1443.02
# 1        2   585.143   372.558   1462.87   697.174   348.385   1442.69
# 2    2.005   585.515   376.922   1462.07   697.522   352.641   1442.18
# 3     2.01   586.007   382.054   1460.43   697.966   357.039   1441.33
# 4    2.015   586.421   386.697   1459.07   698.611   361.568    1440.2
# 5     2.02   586.908   391.577   1457.38   699.211   366.154   1438.95
# 6    2.025   587.515    396.74   1455.17   699.901   371.103   1437.29
# 7     2.03   588.019    402.05   1452.65   700.525   376.198   1435.22
# 8    2.035   588.618   407.375   1449.85   701.273   381.439   1432.85
# 9     2.04   589.246   413.162   1446.58   702.064   387.053   1429.77
# 10   2.045   589.763   418.651   1443.23   702.671   392.314   1426.87
# 11    2.05   590.349   424.363    1439.2   703.435   397.975   1423.29
# 12   2.055   591.058   430.141   1434.81   704.115    403.63    1419.3
# 13    2.06    591.68   435.951   1429.94    704.87   409.393   1414.82
# 14   2.065   592.309   441.836   1424.55   705.611   415.181   1409.79
# 15    2.07   592.926   447.663   1418.66   706.421   421.114   1404.17
# 16   2.075   593.564   453.508   1412.28   707.127   426.811    1398.2
# 17    2.08   594.233   459.321   1405.34   707.801   432.561   1391.65
# 18   2.085   594.747   465.107   1397.92   708.416   438.254   1384.67
# 19    2.09   595.277   470.887   1389.93   708.965   443.884   1377.23
# 20   2.095   595.789   476.627   1381.52   709.766   449.892   1368.47
# 21     2.1   596.259   482.326   1372.55    710.32   455.521   1359.85
# 12          0         0         0
# 13          0         0         0
# 14          0         0         0
# 15          0         0         0
# 16          0         0         0
# 17          0         0         0
# 18          0         0         0
# 19          0         0         0
# 20          0         0         0
# 21          0         0         0
# 22          0         0         0
# 23          0         0         0
# 24          0         0         0
# 25          0         0         0
# 26          0         0         0
# 27          0         0         0
# 28          0         0         0
# 29          0         0         0
# ..        ...       ...       ...
# 234         0         0         0
# 235         0         0         0
# 236         0         0         0
# 237         0         0         0
# 238         0         0         0
# 239         0         0         0
# 240         0         0         0
# 241         0         0         0
# 242         0         0         0
# 243         0         0         0
# 244         0         0         0
# 245         0         0         0
# 246         0         0         0
# 247         0         0         0
# 248         0         0         0
# 249         0         0         0
# 250         0         0         0
# 251         0         0         0
# 252         0         0         0
# 253         0         0         0
# 254         0         0         0
# 255         0         0         0
# 256         0         0         0
# 257         0         0         0
# 258         0         0         0
# 259         0         0         0
# 260         0         0         0
# 261         0         0         0
# 262         0         0         0
# 263         0         0         0
#
# [264 rows x 121 columns]

# %%
df = df.astype(float)

# %%
df.shape[1]
data = df.values
pos_data=data[:,1:-1]
pos_data.shape
# Out:
# (264, 119)

# %%
plt.plot(df['R.ASIS_X'], 'r', label = 'X')
plt.plot(df['R.ASIS_Y'], 'b', label = 'Y')
plt.plot(df['R.ASIS_Z'], 'g', label = 'Z')
plt.legend()
plt.show()

# %%
from vpython import *
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
scene=canvas()
scene.width = 400
scene.height = 400
scene.background = color.black
x = 1000
y = 1000
z = 1000

#scene.center=vector(0, y , 0)
scene.camera.pos = vector(0, 0 ,0)
#scene.camera.axis = vector(0, 0, 0)



arrow(pos=vec(0,0,0), axis = vec(500,0,0), color=color.green)
arrow(pos=vec(0,0,0), axis = vec(0,500,0), color=color.red)
arrow(pos=vec(0,0,0), axis = vec(0,0,500), color=color.blue)


balls = []

i = 0
for i in range(pos_data.shape[1]-2):
    
    if i % 3==0:
        ball = sphere(pos=vec(pos_data[0,i],pos_data[0,i+2],pos_data[0,i+1]), radius=20, color=color.orange, make_trail = False, visible = True)
        balls.append(ball)

    i = i +1

    
    
    
k = 0
j = 1

while j < (len(balls)):
    rate(100)
    
    for k in range(pos_data.shape[1]-2):
        
        if k % 3==0:
            
            if pos_data[j,k] != 0:
                balls[j] = pos = vec(pos_data[j,k],pos_data[j,k+2], pos_data[j,k+1])
            else:
                balls[j] = visible = False
            
        k = k + 1
    j = j + 1
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
len(balls)
# Out:
# 39

# %%
j
# Out:
# 39

# %%
pos_data
# Out:
# array([[ 584.802 ,  368.122 , 1463.72  , ...,   94.0016,    0.    ,
#            0.    ],
#        [ 585.143 ,  372.558 , 1462.87  , ...,   94.1124,    0.    ,
#            0.    ],
#        [ 585.515 ,  376.922 , 1462.07  , ...,   94.2271,    0.    ,
#            0.    ],
#        ...,
#        [ 669.984 ,  581.736 , 1445.62  , ...,   91.4326,    0.    ,
#            0.    ],
#        [ 670.2   ,  582.872 , 1431.    , ...,   89.5478,    0.    ,
#            0.    ],
#        [ 670.471 ,  584.059 , 1416.15  , ...,   89.8715,    0.    ,
#            0.    ]])
